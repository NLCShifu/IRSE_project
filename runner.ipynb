# %% [markdown]
# <a href="https://colab.research.google.com/github/NLCShifu/IRSE_project/blob/main/runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First clone github code:

# %%
# !git clone https://github.com/NLCShifu/IRSE_project.git
# %cd IRSE_project
# Out:
# Cloning into 'IRSE_project'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 1), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), done.
# Resolving deltas: 100% (1/1), done.
# /content/IRSE_project/IRSE_project

# %%
# !python src/main.py
# Out:
# Hello world!
